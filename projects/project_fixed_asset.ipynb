# %% [markdown]
# # Project Test

# %%
print("Hello GitHub!")
# Out:
# Hello GitHub!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array = np.arange(0, 10, 0.01)
plt.plot(array, array**2)
